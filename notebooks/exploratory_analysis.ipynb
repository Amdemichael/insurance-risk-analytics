# %% [markdown]
# # Exploratory Data Analysis for Insurance Risk Analytics
#
# This notebook runs the EDA functions from `src/eda.py` to analyze the `MachineLearningRating_v3.txt` dataset.
#
# ## References
# - Pandas Documentation: https://pandas.pydata.org/docs/
# - Seaborn Visualization Guide: https://seaborn.pydata.org/tutorial.html
# - Statistics for Data Science: "Practical Statistics for Data Scientists" by Peter Bruce

# %%
# Import required libraries and the eda module
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..', 'src')))  # Adjust path to src
import eda
import pandas as pd
import matplotlib.pyplot as plt

# Enable inline plotting in notebook
# %matplotlib inline

# Load data with absolute path
data_path = os.path.abspath(os.path.join(os.getcwd(), '..', 'data', 'MachineLearningRating_v3.txt'))
df = eda.load_data(data_path)
# Out:
# d:\Tutorials\KAIM\Weeks\Week 3\insurance-risk-analytics\src\eda.py:32: DtypeWarning: Columns (32,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, sep='|', encoding='utf-8')

# %%
# Load and initialize data
df = eda.load_data('../data/MachineLearningRating_v3.txt')
df.head()
# Out:
# d:\Tutorials\KAIM\Weeks\Week 3\insurance-risk-analytics\src\eda.py:32: DtypeWarning: Columns (32,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, sep='|', encoding='utf-8')
#    UnderwrittenCoverID  PolicyID TransactionMonth  IsVATRegistered  \
# 0               145249     12827       2015-03-01             True
# 1               145249     12827       2015-05-01             True
# 2               145249     12827       2015-07-01             True
# 3               145255     12827       2015-05-01             True
# 4               145255     12827       2015-07-01             True
#
#   Citizenship          LegalType Title Language                 Bank  \
# 0              Close Corporation    Mr  English  First National Bank
# 1              Close Corporation    Mr  English  First National Bank
# 2              Close Corporation    Mr  English  First National Bank
# ...

# %%
# Summarize data
df = eda.summarize_data(df)
# Out:
# Descriptive Statistics for Numerical Features:
#        TotalPremium   TotalClaims    SumInsured  CalculatedPremiumPerTerm  \
# count  1.000098e+06  1.000098e+06  1.000098e+06              1.000098e+06
# mean   6.190550e+01  6.486119e+01  6.041727e+05              1.178757e+02
# std    2.302845e+02  2.384075e+03  1.508332e+06              3.997017e+02
# min   -7.825768e+02 -1.200241e+04  1.000000e-02              0.000000e+00
# 25%    0.000000e+00  0.000000e+00  5.000000e+03              3.224800e+00
# 50%    2.178333e+00  0.000000e+00  7.500000e+03              8.436900e+00
# 75%    2.192982e+01  0.000000e+00  2.500000e+05              9.000000e+01
# max    6.528260e+04  3.930921e+05  1.263620e+07              7.442217e+04
#
#        CustomValueEstimate
# count         2.204560e+05
# mean          2.255311e+05
# std           5.645157e+05
# min           2.000000e+04
# 25%           1.350000e+05
# 50%           2.200000e+05
# 75%           2.800000e+05
# max           2.655000e+07
# ...

# %%
# Assess data quality
df = eda.assess_data_quality(df)
# Out:
# Missing Values (Count and Percentage):
#                           Missing  Percentage
# UnderwrittenCoverID             0        0.00
# PolicyID                        0        0.00
# TransactionMonth                0        0.00
# IsVATRegistered                 0        0.00
# Citizenship                     0        0.00
# LegalType                       0        0.00
# Title                           0        0.00
# Language                        0        0.00
# Bank                        40232        4.02
# AccountType                 40232        4.02
# MaritalStatus                   0        0.00
# Gender                          0        0.00
# Country                         0        0.00
# Province                        0        0.00
# PostalCode                      0        0.00
# MainCrestaZone                  0        0.00
# SubCrestaZone                   0        0.00
# ItemType                        0        0.00
# ...

# %%
# Plot distributions
eda.plot_distributions(df)

# %%
# Perform bivariate analysis
eda.bivariate_analysis(df)

# %%
# Detect outliers
df = eda.detect_outliers(df)

# %%
# Analyze trends over geography
eda.trends_over_geography(df)

# %%
# Calculate group statistics
eda.group_statistics(df)
# Out:
# LossRatio by VehicleType:
# VehicleType
# Light Commercial     3.648446e-01
# Heavy Commercial     9.771741e+09
# Medium Commercial    1.623684e+10
# Passenger Vehicle    2.881328e+10
# Bus                  1.202486e+11
# Name: LossRatio, dtype: float64
#
# LossRatio by Gender:
# Gender
# None             2.436688e-01
# Female           4.394826e+09
# Not specified    2.803132e+10
# Male             3.591741e+10
# Name: LossRatio, dtype: float64

# %%
# Perform statistical tests
eda.statistical_tests(df)
# Out:
# Shapiro-Wilk Test for TotalClaims: Statistic=0.009, p-value=0.000
# Reject null hypothesis: TotalClaims is not normally distributed.
# c:\Users\hp\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\stats\_morestats.py:1816: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")

# %%
# Generate creative visualizations
eda.creative_visualizations(df)

# %%
# Save cleaned data
df.to_csv('../data/processed/cleaned_data.csv', index=False)
print("EDA complete. Visualizations saved in data/plots/. Cleaned data saved as cleaned_data.csv.")
# Out:
# EDA complete. Visualizations saved in data/plots/. Cleaned data saved as cleaned_data.csv.

# %%
# Optional: Display a sample of cleaned data
df.head()
# Out:
#    UnderwrittenCoverID  PolicyID TransactionMonth  IsVATRegistered  \
# 0               145249     12827       2015-03-01             True
# 1               145249     12827       2015-05-01             True
# 2               145249     12827       2015-07-01             True
# 3               145255     12827       2015-05-01             True
# 4               145255     12827       2015-07-01             True
#
#   Citizenship          LegalType Title Language                 Bank  \
# 0              Close Corporation    Mr  English  First National Bank
# 1              Close Corporation    Mr  English  First National Bank
# 2              Close Corporation    Mr  English  First National Bank
# 3              Close Corporation    Mr  English  First National Bank
# 4              Close Corporation    Mr  English  First National Bank
#
#        AccountType  ... CoverCategory   CoverType            CoverGroup  \
# ...
